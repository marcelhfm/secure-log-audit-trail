# %%
import serial
import time
from IPython.display import display, clear_output
from cryptography.hazmat.primitives.ciphers.aead import AESCCM

# %%
SERIAL_PORT = "/dev/cu.usbmodem1101"
BAUD_RATE = 115200

ser = serial.Serial(SERIAL_PORT, BAUD_RATE, timeout=0.1)
time.sleep(2)               # give the ESP time to reboot+enumerate
ser.reset_input_buffer()    # drop any boot messages

# %%
def send_ping_and_wait(timeout_s=5.0):
    ser.write(b"ping\n")
    deadline = time.time() + timeout_s
    while time.time() < deadline:
        raw = ser.readline()
        if not raw:
            continue
        line = raw.decode(errors="ignore").strip()
        # debug: print any other lines (log lines) you happen to see
        if line.startswith("ping:"):
            print("OK:", line)
            return
        else:
            print("  log >", line)
    raise TimeoutError("no ping reply in time")

# %%
def send_log_dump_and_wait(timeout_s=60.0):
    """
    Send the dump command, wait for a line beginning with "log_dump:",
    parse the hex data that follows, and return it as bytes.
    Any other lines (ESP_LOGx… etc.) are printed and skipped.
    """
    # fire off the dump command
    ser.write(b"log_dump\n")
    deadline = time.time() + timeout_s

    audit_logs = []
    while time.time() < deadline:
        raw = ser.readline()
        if not raw:
            # no data yet
            continue

        line = raw.decode(errors="ignore").strip()
        # is this our dump line?
        if line.startswith("log_dump:"):
            # extract the hex chunk after the colon
            hexstr = line.split(":", 1)[1]
            try:
                data = bytes.fromhex(hexstr)
                audit_logs.append(data)
            except ValueError:
                raise ValueError(f"Invalid hex in dump: {hexstr!r}")

        if line.startswith("log_dump_end:"):
            print(f"footer: received {len(audit_logs)} logs.")
            return audit_logs
            
        # otherwise it's just a normal log message—print it and keep waiting
        print("  log >", line)

    print(f"timeout: received {len(audit_logs)} logs.")
    return audit_logs

# %%
def get_key(timeout_s=10.0):
    """
    Send the dump command, wait for a line beginning with "log_dump:",
    parse the hex data that follows, and return it as bytes.
    Any other lines (ESP_LOGx… etc.) are printed and skipped.
    """
    # fire off the dump command
    ser.write(b"get_key\n")
    deadline = time.time() + timeout_s

    while time.time() < deadline:
        raw = ser.readline()
        if not raw:
            # no data yet
            continue

        line = raw.decode(errors="ignore").strip()
        # is this our dump line?
        if line.startswith("get_key:"):
            # extract the hex chunk after the colon
            hexstr = line.split(":", 1)[1]
            try:
                key = bytes.fromhex(hexstr)
                return key
            except ValueError:
                raise ValueError(f"Invalid hex in dump: {hexstr!r}")

        if line.startswith("get_key:"):
            print(f"footer: received {len(audit_logs)} logs.")
            return audit_logs

        # otherwise it's just a normal log message—print it and keep waiting
        print("  log >", line)

    raise TimeoutError("did not get response in time")

# %%
def reset(timeout_s=10.0):
    """
    Send the dump command, wait for a line beginning with "log_dump:",
    parse the hex data that follows, and return it as bytes.
    Any other lines (ESP_LOGx… etc.) are printed and skipped.
    """
    # fire off the dump command
    ser.write(b"reset\n")
    deadline = time.time() + timeout_s

    while time.time() < deadline:
        raw = ser.readline()
        if not raw:
            # no data yet
            continue

        line = raw.decode(errors="ignore").strip()
        # is this our dump line?
        if line.startswith("reset:ok"):
            print("reset success")

        if line.startswith("reset:fail"):
            print("reset fail")

        # otherwise it's just a normal log message—print it and keep waiting
        print("  log >", line)

    raise TimeoutError("did not get response in time")

# %%
def verify_logs(audit_logs, key):
    """
    structure log: 
        - first 12 bytes = nonce
        - next 4 bytes = ad (timestamp)
        - next x bytes = ciphertext
        - last 16 bytes = prev_tag
    """

    aesccm = AESCCM(key, tag_length=16)
    results = []
    expected_nonce = None
    NONCE_LEN = 12

    for idx, record in enumerate(audit_logs):
        if len(record) < NONCE_LEN + 4 + 16:
            raise ValueError(f"Record {idx} too short")

        nonce      = record[:NONCE_LEN]
        aad        = record[NONCE_LEN:NONCE_LEN+4]
        ciphertext = record[NONCE_LEN+4:-16]
        auth_tag   = record[-16:]                # full tag

        # compare the 12-byte nonce against the 12-byte prefix of the previous tag
        if expected_nonce is not None and nonce != expected_nonce:
            raise ValueError(f"Chain broken at record {idx}")

        # decrypt with nonce (12B), ciphertext+tag, and aad
        plaintext = aesccm.decrypt(nonce, ciphertext + auth_tag, aad)

        # schedule next expected_nonce = first 12 bytes of this tag
        expected_nonce = auth_tag[:NONCE_LEN]

        timestamp = int.from_bytes(aad, "little")
        results.append((timestamp, plaintext))

    return results

# %%
reset()
# Out:
#   log > D (1130673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1130673) ringbuf_flash: WRITING hdr @ offset=55203 len=88 crc=0x74570880
#   log > D (1130673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1130673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1130673) nvs: nvs_set_blob log_secure 20
#   log > D (1130673) nvs: nvs_close 728
#   log > D (1130673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1130673) nvs: nvs_set_blob meta 44
#   log > D (1130673) nvs: nvs_close 729
#   log > D (1135673) log_secure: logging secure. ts=1135673
#   log > D (1135673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1135673) ringbuf_flash: WRITING hdr @ offset=55303 len=88 crc=0x273373089
#   log > D (1135673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1135673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1135673) nvs: nvs_set_blob log_secure 20
#   log > D (1135673) nvs: nvs_close 730
#   log > D (1135673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1135673) nvs: nvs_set_blob meta 44
#   log > D (1135673) nvs: nvs_close 731
#   log > D (1140673) log_secure: logging secure. ts=1140673
#   log > D (1140673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1140673) ringbuf_flash: WRITING hdr @ offset=55403 len=88 crc=0x2502729914
#   log > D (1140673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1140673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1140673) nvs: nvs_set_blob log_secure 20
#   log > D (1140673) nvs: nvs_close 732
#   log > D (1140673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1140673) nvs: nvs_set_blob meta 44
#   log > D (1140673) nvs: nvs_close 733
#   log > D (1145673) log_secure: logging secure. ts=1145673
#   log > D (1145673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1145673) ringbuf_flash: WRITING hdr @ offset=55503 len=88 crc=0x273671142
#   log > D (1145673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1145673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1145673) nvs: nvs_set_blob log_secure 20
#   log > D (1145673) nvs: nvs_close 734
#   log > D (1145673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1145673) nvs: nvs_set_blob meta 44
#   log > D (1145673) nvs: nvs_close 735
#   log > D (1150673) log_secure: logging secure. ts=1150673
#   log > D (1150673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1150673) ringbuf_flash: WRITING hdr @ offset=55603 len=88 crc=0x1020335580
#   log > D (1150673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1150673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1150673) nvs: nvs_set_blob log_secure 20
#   log > D (1150673) nvs: nvs_close 736
#   log > D (1150673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1150673) nvs: nvs_set_blob meta 44
#   log > D (1150673) nvs: nvs_close 737
#   log > D (1155673) log_secure: logging secure. ts=1155673
#   log > D (1155673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1155673) ringbuf_flash: WRITING hdr @ offset=55703 len=88 crc=0x3862989448
#   log > D (1155673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1155673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1155673) nvs: nvs_set_blob log_secure 20
#   log > D (1155673) nvs: nvs_close 738
#   log > D (1155673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1155673) nvs: nvs_set_blob meta 44
#   log > D (1155673) nvs: nvs_close 739
#   log > D (1160673) log_secure: logging secure. ts=1160673
#   log > D (1160673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1160673) ringbuf_flash: WRITING hdr @ offset=55803 len=88 crc=0x3657002652
#   log > D (1160673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1160673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1160673) nvs: nvs_set_blob log_secure 20
#   log > D (1160673) nvs: nvs_close 740
#   log > D (1160673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1160673) nvs: nvs_set_blob meta 44
#   log > D (1160673) nvs: nvs_close 741
#   log > D (1165673) log_secure: logging secure. ts=1165673
#   log > D (1165673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1165673) ringbuf_flash: WRITING hdr @ offset=55903 len=88 crc=0x1251994609
#   log > D (1165673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1165673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1165673) nvs: nvs_set_blob log_secure 20
#   log > D (1165673) nvs: nvs_close 742
#   log > D (1165673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1165673) nvs: nvs_set_blob meta 44
#   log > D (1165673) nvs: nvs_close 743
#   log > D (1170673) log_secure: logging secure. ts=1170673
#   log > D (1170673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1170673) ringbuf_flash: WRITING hdr @ offset=56003 len=88 crc=0x2718104393
#   log > D (1170673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1170673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1170673) nvs: nvs_set_blob log_secure 20
#   log > D (1170673) nvs: nvs_close 744
#   log > D (1170673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1170673) nvs: nvs_set_blob meta 44
#   log > D (1170673) nvs: nvs_close 745
#   log > D (1175673) log_secure: logging secure. ts=1175673
#   log > D (1175673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1175673) ringbuf_flash: WRITING hdr @ offset=56103 len=88 crc=0x3426269547
#   log > D (1175673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1175673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1175673) nvs: nvs_set_blob log_secure 20
#   log > D (1175673) nvs: nvs_close 746
#   log > D (1175673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1175673) nvs: nvs_set_blob meta 44
#   log > D (1175673) nvs: nvs_close 747
#   log > D (1180673) log_secure: logging secure. ts=1180673
#   log > D (1180673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1180673) ringbuf_flash: WRITING hdr @ offset=56203 len=88 crc=0x2505093594
#   log > D (1180673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1180673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1180673) nvs: nvs_set_blob log_secure 20
#   log > D (1180673) nvs: nvs_close 748
#   log > D (1180673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1180673) nvs: nvs_set_blob meta 44
#   log > D (1180673) nvs: nvs_close 749
#   log > D (1185673) log_secure: logging secure. ts=1185673
#   log > D (1185673) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1185673) ringbuf_flash: WRITING hdr @ offset=56303 len=88 crc=0x1387773122
#   log > D (1185673) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1185673) nvs: nvs_open_from_partition rb_log 1
#   log > D (1185673) nvs: nvs_set_blob log_secure 20
#   log > D (1185673) nvs: nvs_close 750
#   log > D (1185673) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1185673) nvs: nvs_set_blob meta 44
#   log > D (1185723) nvs: nvs_close 751
#   log > D (1190723) log_secure: logging secure. ts=1190723
#   log > D (1190723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1190723) ringbuf_flash: WRITING hdr @ offset=56403 len=88 crc=0x378981086
#   log > D (1190723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1190723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1190723) nvs: nvs_set_blob log_secure 20
#   log > D (1190723) nvs: nvs_close 752
#   log > D (1190723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1190723) nvs: nvs_set_blob meta 44
#   log > D (1190723) nvs: nvs_close 753
#   log > D (1195723) log_secure: logging secure. ts=1195723
#   log > D (1195723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1195723) ringbuf_flash: WRITING hdr @ offset=56503 len=88 crc=0x1058760231
#   log > D (1195723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1195723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1195723) nvs: nvs_set_blob log_secure 20
#   log > D (1195723) nvs: nvs_close 754
#   log > D (1195723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1195723) nvs: nvs_set_blob meta 44
#   log > D (1195723) nvs: nvs_close 755
#   log > D (1200723) log_secure: logging secure. ts=1200723
#   log > D (1200723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1200723) ringbuf_flash: WRITING hdr @ offset=56603 len=88 crc=0x1445840326
#   log > D (1200723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1200723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1200723) nvs: nvs_set_blob log_secure 20
#   log > D (1200723) nvs: nvs_close 756
#   log > D (1200723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1200723) nvs: nvs_set_blob meta 44
#   log > D (1200723) nvs: nvs_close 757
#   log > D (1205723) log_secure: logging secure. ts=1205723
#   log > D (1205723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1205723) ringbuf_flash: WRITING hdr @ offset=56703 len=88 crc=0x1461547858
#   log > D (1205723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1205723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1205723) nvs: nvs_set_blob log_secure 20
#   log > D (1205723) nvs: nvs_close 758
#   log > D (1205723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1205723) nvs: nvs_set_blob meta 44
#   log > D (1205723) nvs: nvs_close 759
#   log > D (1210723) log_secure: logging secure. ts=1210723
#   log > D (1210723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1210723) ringbuf_flash: WRITING hdr @ offset=56803 len=88 crc=0x3448759512
#   log > D (1210723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1210723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1210723) nvs: nvs_set_blob log_secure 20
#   log > D (1210723) nvs: nvs_close 760
#   log > D (1210723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1210723) nvs: nvs_set_blob meta 44
#   log > D (1210723) nvs: nvs_close 761
#   log > D (1215723) log_secure: logging secure. ts=1215723
#   log > D (1215723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1215723) ringbuf_flash: WRITING hdr @ offset=56903 len=88 crc=0x2043535482
#   log > D (1215723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1215723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1215723) nvs: nvs_set_blob log_secure 20
#   log > D (1215723) nvs: nvs_close 762
#   log > D (1215723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1215723) nvs: nvs_set_blob meta 44
#   log > D (1215723) nvs: nvs_close 763
#   log > D (1220723) log_secure: logging secure. ts=1220723
#   log > D (1220723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1220723) ringbuf_flash: WRITING hdr @ offset=57003 len=88 crc=0x3692717231
#   log > D (1220723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1220723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1220723) nvs: nvs_set_blob log_secure 20
#   log > D (1220723) nvs: nvs_close 764
#   log > D (1220723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1220723) nvs: nvs_set_blob meta 44
#   log > D (1220723) nvs: nvs_close 765
#   log > D (1225723) log_secure: logging secure. ts=1225723
#   log > D (1225723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1225723) ringbuf_flash: WRITING hdr @ offset=57103 len=88 crc=0x3699099749
#   log > D (1225723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1225723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1225723) nvs: nvs_set_blob log_secure 20
#   log > D (1225723) nvs: nvs_close 766
#   log > D (1225723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1225723) nvs: nvs_set_blob meta 44
#   log > D (1225723) nvs: nvs_close 767
#   log > D (1230723) log_secure: logging secure. ts=1230723
#   log > D (1230723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1230723) ringbuf_flash: WRITING hdr @ offset=57203 len=88 crc=0x1943066115
#   log > D (1230723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1230723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1230723) nvs: nvs_set_blob log_secure 20
#   log > D (1230723) nvs: nvs_close 768
#   log > D (1230723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1230723) nvs: nvs_set_blob meta 44
#   log > D (1230723) nvs: nvs_close 769
#   log > D (1235723) log_secure: logging secure. ts=1235723
#   log > D (1235723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1235723) ringbuf_flash: WRITING hdr @ offset=57303 len=88 crc=0x4025047310
#   log > D (1235723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1235723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1235723) nvs: nvs_set_blob log_secure 20
#   log > D (1235723) nvs: nvs_close 770
#   log > D (1235723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1235723) nvs: nvs_set_blob meta 44
#   log > D (1235723) nvs: nvs_close 771
#   log > I (1239303) main: received command. cmd=reset
#   log > D (1239303) ringbuf_flash: load_meta: deemed this the first load, intializing meta and erasing flash partition
#   log > D (1239553) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1239553) nvs: nvs_open_from_partition rb_log 1
#   log > D (1239553) nvs: nvs_set_blob log_secure 20
#   log > D (1239563) nvs: nvs_close 772
#   log > D (1239563) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1239563) nvs: nvs_erase_key meta
#   log > D (1239563) nvs: nvs_erase_key key_fetched
#   log > D (1239563) nvs: nvs_close 773
#   log > D (1239563) ringbuf_flash: partition find successful. label=log_secure
#   log > D (1239563) nvs: nvs_open_from_partition rb_log 1
#   log > D (1239563) nvs: nvs_get_str_or_blob log_secure
#   log > D (1239563) ringbuf_flash: load_meta: successfully loaded meta. version=1
#   log > D (1239563) nvs: nvs_close 774
#   log > D (1239563) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1239563) nvs: nvs_get_str_or_blob meta
#   log > D (1239563) log_secure: detected first boot. generating aead key
#   log > D (1239563) nvs: nvs_set_blob meta 44
#   log > D (1239563) nvs: nvs_close 775
# reset success
#   log > reset:ok
#   log > D (1240723) log_secure: logging secure. ts=1240723
#   log > D (1240723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1240723) ringbuf_flash: WRITING hdr @ offset=100 len=88 crc=0x2128951591
#   log > D (1240723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1240723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1240723) nvs: nvs_set_blob log_secure 20
#   log > D (1240723) nvs: nvs_close 776
#   log > D (1240723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1240723) nvs: nvs_set_blob meta 44
#   log > D (1240723) nvs: nvs_close 777
#   log > D (1245723) log_secure: logging secure. ts=1245723
#   log > D (1245723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1245723) ringbuf_flash: WRITING hdr @ offset=200 len=88 crc=0x2027816455
#   log > D (1245723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1245723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1245723) nvs: nvs_set_blob log_secure 20
#   log > D (1245723) nvs: nvs_close 778
#   log > D (1245723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1245723) nvs: nvs_set_blob meta 44
#   log > D (1245723) nvs: nvs_close 779
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 reset()
#
# Cell In[27], line 28, in reset(timeout_s)
#      25     # otherwise it's just a normal log message—print it and keep waiting
#      26     print("  log >", line)
# ---> 28 raise TimeoutError("did not get response in time")
#
# TimeoutError: did not get response in time

# %%
send_ping_and_wait()
# Out:
#   log > I (1249923) main: received command. cmd=ping
# OK: ping:pong

# %%
key = get_key()
# Out:
#   log > D (1250723) log_secure: logging secure. ts=1250723
#   log > D (1250723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1250723) ringbuf_flash: WRITING hdr @ offset=300 len=88 crc=0x3230998246
#   log > D (1250723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1250723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1250723) nvs: nvs_set_blob log_secure 20
#   log > D (1250723) nvs: nvs_close 780
#   log > D (1250723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1250723) nvs: nvs_set_blob meta 44
#   log > D (1250723) nvs: nvs_close 781
#   log > I (1255393) main: received command. cmd=get_key
#   log > D (1255393) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1255393) nvs: nvs_get_str_or_blob key_fetched
#   log > D (1255393) nvs: nvs_set_blob key_fetched 2

# %%
audit_logs = send_log_dump_and_wait()
# Out:
#   log > D (1265723) log_secure: logging secure. ts=1265723
#   log > D (1265723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1265723) ringbuf_flash: WRITING hdr @ offset=600 len=88 crc=0x2227904026
#   log > D (1265723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1265723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1265723) nvs: nvs_set_blob log_secure 20
#   log > D (1265723) nvs: nvs_close 792
#   log > D (1265723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1265723) nvs: nvs_set_blob meta 44
#   log > D (1265723) nvs: nvs_close 793
#   log > D (1270723) log_secure: logging secure. ts=1270723
#   log > D (1270723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1270723) ringbuf_flash: WRITING hdr @ offset=700 len=88 crc=0x2520266188
#   log > D (1270723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1270723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1270723) nvs: nvs_set_blob log_secure 20
#   log > D (1270723) nvs: nvs_close 794
#   log > D (1270723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1270723) nvs: nvs_set_blob meta 44
#   log > D (1270723) nvs: nvs_close 795
#   log > D (1275723) log_secure: logging secure. ts=1275723
#   log > D (1275723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1275723) ringbuf_flash: WRITING hdr @ offset=800 len=88 crc=0x4047757408
#   log > D (1275723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1275723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1275723) nvs: nvs_set_blob log_secure 20
#   log > D (1275723) nvs: nvs_close 796
#   log > D (1275723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1275723) nvs: nvs_set_blob meta 44
#   log > D (1275723) nvs: nvs_close 797
#   log > D (1280723) log_secure: logging secure. ts=1280723
#   log > D (1280723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1280723) ringbuf_flash: WRITING hdr @ offset=900 len=88 crc=0x306961737
#   log > D (1280723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1280723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1280723) nvs: nvs_set_blob log_secure 20
#   log > D (1280723) nvs: nvs_close 798
#   log > D (1280723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1280723) nvs: nvs_set_blob meta 44
#   log > D (1280723) nvs: nvs_close 799
#   log > D (1285723) log_secure: logging secure. ts=1285723
#   log > D (1285723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1285723) ringbuf_flash: WRITING hdr @ offset=1000 len=88 crc=0x3637424298
#   log > D (1285723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1285723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1285723) nvs: nvs_set_blob log_secure 20
#   log > D (1285723) nvs: nvs_close 800
#   log > D (1285723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1285723) nvs: nvs_set_blob meta 44
#   log > D (1285723) nvs: nvs_close 801
#   log > D (1290723) log_secure: logging secure. ts=1290723
#   log > D (1290723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1290723) ringbuf_flash: WRITING hdr @ offset=1100 len=88 crc=0x4216371078
#   log > D (1290723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1290723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1290723) nvs: nvs_set_blob log_secure 20
#   log > D (1290723) nvs: nvs_close 802
#   log > D (1290723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1290723) nvs: nvs_set_blob meta 44
#   log > D (1290723) nvs: nvs_close 803
#   log > D (1295723) log_secure: logging secure. ts=1295723
#   log > D (1295723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1295723) ringbuf_flash: WRITING hdr @ offset=1200 len=88 crc=0x781762478
#   log > D (1295723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1295723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1295723) nvs: nvs_set_blob log_secure 20
#   log > D (1295723) nvs: nvs_close 804
#   log > D (1295723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1295723) nvs: nvs_set_blob meta 44
#   log > D (1295723) nvs: nvs_close 805
#   log > D (1300723) log_secure: logging secure. ts=1300723
#   log > D (1300723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1300723) ringbuf_flash: WRITING hdr @ offset=1300 len=88 crc=0x766879125
#   log > D (1300723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1300723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1300723) nvs: nvs_set_blob log_secure 20
#   log > D (1300723) nvs: nvs_close 806
#   log > D (1300723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1300723) nvs: nvs_set_blob meta 44
#   log > D (1300723) nvs: nvs_close 807
#   log > D (1305723) log_secure: logging secure. ts=1305723
#   log > D (1305723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1305723) ringbuf_flash: WRITING hdr @ offset=1400 len=88 crc=0x3734897344
#   log > D (1305723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1305723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1305723) nvs: nvs_set_blob log_secure 20
#   log > D (1305723) nvs: nvs_close 808
#   log > D (1305723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1305723) nvs: nvs_set_blob meta 44
#   log > D (1305723) nvs: nvs_close 809
#   log > D (1310723) log_secure: logging secure. ts=1310723
#   log > D (1310723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1310723) ringbuf_flash: WRITING hdr @ offset=1500 len=88 crc=0x4255010418
#   log > D (1310723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1310723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1310723) nvs: nvs_set_blob log_secure 20
#   log > D (1310723) nvs: nvs_close 810
#   log > D (1310723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1310723) nvs: nvs_set_blob meta 44
#   log > D (1310723) nvs: nvs_close 811
#   log > D (1315723) log_secure: logging secure. ts=1315723
#   log > D (1315723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1315723) ringbuf_flash: WRITING hdr @ offset=1600 len=88 crc=0x4064705740
#   log > D (1315723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1315723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1315723) nvs: nvs_set_blob log_secure 20
#   log > D (1315723) nvs: nvs_close 812
#   log > D (1315723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1315723) nvs: nvs_set_blob meta 44
#   log > D (1315723) nvs: nvs_close 813
#   log > D (1320723) log_secure: logging secure. ts=1320723
#   log > D (1320723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1320723) ringbuf_flash: WRITING hdr @ offset=1700 len=88 crc=0x3898757997
#   log > D (1320723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1320723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1320723) nvs: nvs_set_blob log_secure 20
#   log > D (1320723) nvs: nvs_close 814
#   log > D (1320723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1320723) nvs: nvs_set_blob meta 44
#   log > D (1320723) nvs: nvs_close 815
#   log > D (1325723) log_secure: logging secure. ts=1325723
#   log > D (1325723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1325723) ringbuf_flash: WRITING hdr @ offset=1800 len=88 crc=0x819461721
#   log > D (1325723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1325723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1325723) nvs: nvs_set_blob log_secure 20
#   log > D (1325723) nvs: nvs_close 816
#   log > D (1325723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1325723) nvs: nvs_set_blob meta 44
#   log > D (1325723) nvs: nvs_close 817
#   log > D (1330723) log_secure: logging secure. ts=1330723
#   log > D (1330723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1330723) ringbuf_flash: WRITING hdr @ offset=1900 len=88 crc=0x320396975
#   log > D (1330723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1330723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1330723) nvs: nvs_set_blob log_secure 20
#   log > D (1330723) nvs: nvs_close 818
#   log > D (1330723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1330723) nvs: nvs_set_blob meta 44
#   log > D (1330723) nvs: nvs_close 819
#   log > D (1335723) log_secure: logging secure. ts=1335723
#   log > D (1335723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1335723) ringbuf_flash: WRITING hdr @ offset=2000 len=88 crc=0x66564772
#   log > D (1335723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1335723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1335723) nvs: nvs_set_blob log_secure 20
#   log > D (1335723) nvs: nvs_close 820
#   log > D (1335723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1335723) nvs: nvs_set_blob meta 44
#   log > D (1335723) nvs: nvs_close 821
#   log > D (1340723) log_secure: logging secure. ts=1340723
#   log > D (1340723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1340723) ringbuf_flash: WRITING hdr @ offset=2100 len=88 crc=0x556359018
#   log > D (1340723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1340723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1340723) nvs: nvs_set_blob log_secure 20
#   log > D (1340723) nvs: nvs_close 822
#   log > D (1340723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1340723) nvs: nvs_set_blob meta 44
#   log > D (1340723) nvs: nvs_close 823
#   log > D (1345723) log_secure: logging secure. ts=1345723
#   log > D (1345723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1345723) ringbuf_flash: WRITING hdr @ offset=2200 len=88 crc=0x279296936
#   log > D (1345723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1345723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1345723) nvs: nvs_set_blob log_secure 20
#   log > D (1345723) nvs: nvs_close 824
#   log > D (1345723) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1345723) nvs: nvs_set_blob meta 44
#   log > D (1345723) nvs: nvs_close 825
#   log > D (1350723) log_secure: logging secure. ts=1350723
#   log > D (1350723) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1350723) ringbuf_flash: WRITING hdr @ offset=2300 len=88 crc=0x2070849569
#   log > D (1350723) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1350723) nvs: nvs_open_from_partition rb_log 1
#   log > D (1350723) nvs: nvs_set_blob log_secure 20
#   log > D (1350773) nvs: nvs_close 826
#   log > D (1350773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1350773) nvs: nvs_set_blob meta 44
#   log > D (1350773) nvs: nvs_close 827
#   log > D (1355773) log_secure: logging secure. ts=1355773
#   log > D (1355773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1355773) ringbuf_flash: WRITING hdr @ offset=2400 len=88 crc=0x289807357
#   log > D (1355773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1355773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1355773) nvs: nvs_set_blob log_secure 20
#   log > D (1355773) nvs: nvs_close 828
#   log > D (1355773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1355773) nvs: nvs_set_blob meta 44
#   log > D (1355773) nvs: nvs_close 829
#   log > D (1360773) log_secure: logging secure. ts=1360773
#   log > D (1360773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1360773) ringbuf_flash: WRITING hdr @ offset=2500 len=88 crc=0x1227532559
#   log > D (1360773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1360773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1360773) nvs: nvs_set_blob log_secure 20
#   log > D (1360773) nvs: nvs_close 830
#   log > D (1360773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1360773) nvs: nvs_set_blob meta 44
#   log > D (1360773) nvs: nvs_close 831
#   log > D (1365773) log_secure: logging secure. ts=1365773
#   log > D (1365773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1365773) ringbuf_flash: WRITING hdr @ offset=2600 len=88 crc=0x508641767
#   log > D (1365773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1365773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1365773) nvs: nvs_set_blob log_secure 20
#   log > D (1365773) nvs: nvs_close 832
#   log > D (1365773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1365773) nvs: nvs_set_blob meta 44
#   log > D (1365773) nvs: nvs_close 833
#   log > D (1370773) log_secure: logging secure. ts=1370773
#   log > D (1370773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1370773) ringbuf_flash: WRITING hdr @ offset=2700 len=88 crc=0x3448389522
#   log > D (1370773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1370773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1370773) nvs: nvs_set_blob log_secure 20
#   log > D (1370773) nvs: nvs_close 834
#   log > D (1370773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1370773) nvs: nvs_set_blob meta 44
#   log > D (1370773) nvs: nvs_close 835
#   log > D (1375773) log_secure: logging secure. ts=1375773
#   log > D (1375773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1375773) ringbuf_flash: WRITING hdr @ offset=2800 len=88 crc=0x2983214374
#   log > D (1375773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1375773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1375773) nvs: nvs_set_blob log_secure 20
#   log > D (1375773) nvs: nvs_close 836
#   log > D (1375773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1375773) nvs: nvs_set_blob meta 44
#   log > D (1375773) nvs: nvs_close 837
#   log > D (1380773) log_secure: logging secure. ts=1380773
#   log > D (1380773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1380773) ringbuf_flash: WRITING hdr @ offset=2900 len=88 crc=0x1697132309
#   log > D (1380773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1380773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1380773) nvs: nvs_set_blob log_secure 20
#   log > D (1380773) nvs: nvs_close 838
#   log > D (1380773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1380773) nvs: nvs_set_blob meta 44
#   log > D (1380773) nvs: nvs_close 839
#   log > D (1385773) log_secure: logging secure. ts=1385773
#   log > D (1385773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1385773) ringbuf_flash: WRITING hdr @ offset=3000 len=88 crc=0x3874173494
#   log > D (1385773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1385773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1385773) nvs: nvs_set_blob log_secure 20
#   log > D (1385773) nvs: nvs_close 840
#   log > D (1385773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1385773) nvs: nvs_set_blob meta 44
#   log > D (1385773) nvs: nvs_close 841
#   log > D (1390773) log_secure: logging secure. ts=1390773
#   log > D (1390773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1390773) ringbuf_flash: WRITING hdr @ offset=3100 len=88 crc=0x3067475710
#   log > D (1390773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1390773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1390773) nvs: nvs_set_blob log_secure 20
#   log > D (1390773) nvs: nvs_close 842
#   log > D (1390773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1390773) nvs: nvs_set_blob meta 44
#   log > D (1390773) nvs: nvs_close 843
#   log > D (1395773) log_secure: logging secure. ts=1395773
#   log > D (1395773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1395773) ringbuf_flash: WRITING hdr @ offset=3200 len=88 crc=0x1972772525
#   log > D (1395773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1395773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1395773) nvs: nvs_set_blob log_secure 20
#   log > D (1395773) nvs: nvs_close 844
#   log > D (1395773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1395773) nvs: nvs_set_blob meta 44
#   log > D (1395773) nvs: nvs_close 845
#   log > D (1400773) log_secure: logging secure. ts=1400773
#   log > D (1400773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1400773) ringbuf_flash: WRITING hdr @ offset=3300 len=88 crc=0x1103702531
#   log > D (1400773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1400773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1400773) nvs: nvs_set_blob log_secure 20
#   log > D (1400773) nvs: nvs_close 846
#   log > D (1400773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1400773) nvs: nvs_set_blob meta 44
#   log > D (1400773) nvs: nvs_close 847
#   log > D (1405773) log_secure: logging secure. ts=1405773
#   log > D (1405773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1405773) ringbuf_flash: WRITING hdr @ offset=3400 len=88 crc=0x1670043628
#   log > D (1405773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1405773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1405773) nvs: nvs_set_blob log_secure 20
#   log > D (1405773) nvs: nvs_close 848
#   log > D (1405773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1405773) nvs: nvs_set_blob meta 44
#   log > D (1405773) nvs: nvs_close 849
#   log > D (1410773) log_secure: logging secure. ts=1410773
#   log > D (1410773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1410773) ringbuf_flash: WRITING hdr @ offset=3500 len=88 crc=0x2646637052
#   log > D (1410773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1410773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1410773) nvs: nvs_set_blob log_secure 20
#   log > D (1410773) nvs: nvs_close 850
#   log > D (1410773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1410773) nvs: nvs_set_blob meta 44
#   log > D (1410773) nvs: nvs_close 851
#   log > D (1415773) log_secure: logging secure. ts=1415773
#   log > D (1415773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1415773) ringbuf_flash: WRITING hdr @ offset=3600 len=88 crc=0x790890564
#   log > D (1415773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1415773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1415773) nvs: nvs_set_blob log_secure 20
#   log > D (1415773) nvs: nvs_close 852
#   log > D (1415773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1415773) nvs: nvs_set_blob meta 44
#   log > D (1415773) nvs: nvs_close 853
#   log > D (1420773) log_secure: logging secure. ts=1420773
#   log > D (1420773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1420773) ringbuf_flash: WRITING hdr @ offset=3700 len=88 crc=0x3822667226
#   log > D (1420773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1420773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1420773) nvs: nvs_set_blob log_secure 20
#   log > D (1420773) nvs: nvs_close 854
#   log > D (1420773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1420773) nvs: nvs_set_blob meta 44
#   log > D (1420773) nvs: nvs_close 855
#   log > D (1425773) log_secure: logging secure. ts=1425773
#   log > D (1425773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1425773) ringbuf_flash: WRITING hdr @ offset=3800 len=88 crc=0x665208691
#   log > D (1425773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1425773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1425773) nvs: nvs_set_blob log_secure 20
#   log > D (1425773) nvs: nvs_close 856
#   log > D (1425773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1425773) nvs: nvs_set_blob meta 44
#   log > D (1425773) nvs: nvs_close 857
#   log > D (1430773) log_secure: logging secure. ts=1430773
#   log > D (1430773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1430773) ringbuf_flash: WRITING hdr @ offset=3900 len=88 crc=0x757157410
#   log > D (1430773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1430773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1430773) nvs: nvs_set_blob log_secure 20
#   log > D (1430773) nvs: nvs_close 858
#   log > D (1430773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1430773) nvs: nvs_set_blob meta 44
#   log > D (1430773) nvs: nvs_close 859
#   log > D (1435773) log_secure: logging secure. ts=1435773
#   log > D (1435773) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1435773) ringbuf_flash: WRITING hdr @ offset=4000 len=88 crc=0x2688607102
#   log > D (1435773) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1435773) nvs: nvs_open_from_partition rb_log 1
#   log > D (1435773) nvs: nvs_set_blob log_secure 20
#   log > D (1435773) nvs: nvs_close 860
#   log > D (1435773) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1435773) nvs: nvs_set_blob meta 44
#   log > D (1435813) nvs: nvs_close 861
#   log > D (1440813) log_secure: logging secure. ts=1440813
#   log > D (1440813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1440813) ringbuf_flash: WRITING hdr @ offset=4100 len=88 crc=0x124169346
#   log > D (1440813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1440813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1440813) nvs: nvs_set_blob log_secure 20
#   log > D (1440813) nvs: nvs_close 862
#   log > D (1440813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1440813) nvs: nvs_set_blob meta 44
#   log > D (1440813) nvs: nvs_close 863
#   log > D (1445813) log_secure: logging secure. ts=1445813
#   log > D (1445813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1445813) ringbuf_flash: WRITING hdr @ offset=4200 len=88 crc=0x2717972596
#   log > D (1445813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1445813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1445813) nvs: nvs_set_blob log_secure 20
#   log > D (1445813) nvs: nvs_close 864
#   log > D (1445813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1445813) nvs: nvs_set_blob meta 44
#   log > D (1445813) nvs: nvs_close 865
#   log > D (1450813) log_secure: logging secure. ts=1450813
#   log > D (1450813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1450813) ringbuf_flash: WRITING hdr @ offset=4300 len=88 crc=0x3983106567
#   log > D (1450813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1450813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1450813) nvs: nvs_set_blob log_secure 20
#   log > D (1450813) nvs: nvs_close 866
#   log > D (1450813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1450813) nvs: nvs_set_blob meta 44
#   log > D (1450813) nvs: nvs_close 867
#   log > D (1455813) log_secure: logging secure. ts=1455813
#   log > D (1455813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1455813) ringbuf_flash: WRITING hdr @ offset=4400 len=88 crc=0x1571146499
#   log > D (1455813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1455813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1455813) nvs: nvs_set_blob log_secure 20
#   log > D (1455813) nvs: nvs_close 868
#   log > D (1455813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1455813) nvs: nvs_set_blob meta 44
#   log > D (1455813) nvs: nvs_close 869
#   log > D (1460813) log_secure: logging secure. ts=1460813
#   log > D (1460813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1460813) ringbuf_flash: WRITING hdr @ offset=4500 len=88 crc=0x2662265715
#   log > D (1460813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1460813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1460813) nvs: nvs_set_blob log_secure 20
#   log > D (1460813) nvs: nvs_close 870
#   log > D (1460813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1460813) nvs: nvs_set_blob meta 44
#   log > D (1460813) nvs: nvs_close 871
#   log > D (1465813) log_secure: logging secure. ts=1465813
#   log > D (1465813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1465813) ringbuf_flash: WRITING hdr @ offset=4600 len=88 crc=0x3608968636
#   log > D (1465813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1465813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1465813) nvs: nvs_set_blob log_secure 20
#   log > D (1465813) nvs: nvs_close 872
#   log > D (1465813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1465813) nvs: nvs_set_blob meta 44
#   log > D (1465813) nvs: nvs_close 873
#   log > D (1470813) log_secure: logging secure. ts=1470813
#   log > D (1470813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1470813) ringbuf_flash: WRITING hdr @ offset=4700 len=88 crc=0x2950830543
#   log > D (1470813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1470813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1470813) nvs: nvs_set_blob log_secure 20
#   log > D (1470813) nvs: nvs_close 874
#   log > D (1470813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1470813) nvs: nvs_set_blob meta 44
#   log > D (1470813) nvs: nvs_close 875
#   log > D (1475813) log_secure: logging secure. ts=1475813
#   log > D (1475813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1475813) ringbuf_flash: WRITING hdr @ offset=4800 len=88 crc=0x1488433071
#   log > D (1475813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1475813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1475813) nvs: nvs_set_blob log_secure 20
#   log > D (1475813) nvs: nvs_close 876
#   log > D (1475813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1475813) nvs: nvs_set_blob meta 44
#   log > D (1475813) nvs: nvs_close 877
#   log > D (1480813) log_secure: logging secure. ts=1480813
#   log > D (1480813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1480813) ringbuf_flash: WRITING hdr @ offset=4900 len=88 crc=0x3262689766
#   log > D (1480813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1480813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1480813) nvs: nvs_set_blob log_secure 20
#   log > D (1480813) nvs: nvs_close 878
#   log > D (1480813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1480813) nvs: nvs_set_blob meta 44
#   log > D (1480813) nvs: nvs_close 879
#   log > D (1485813) log_secure: logging secure. ts=1485813
#   log > D (1485813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1485813) ringbuf_flash: WRITING hdr @ offset=5000 len=88 crc=0x2155406499
#   log > D (1485813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1485813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1485813) nvs: nvs_set_blob log_secure 20
#   log > D (1485813) nvs: nvs_close 880
#   log > D (1485813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1485813) nvs: nvs_set_blob meta 44
#   log > D (1485813) nvs: nvs_close 881
#   log > D (1490813) log_secure: logging secure. ts=1490813
#   log > D (1490813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1490813) ringbuf_flash: WRITING hdr @ offset=5100 len=88 crc=0x356712963
#   log > D (1490813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1490813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1490813) nvs: nvs_set_blob log_secure 20
#   log > D (1490813) nvs: nvs_close 882
#   log > D (1490813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1490813) nvs: nvs_set_blob meta 44
#   log > D (1490813) nvs: nvs_close 883
#   log > D (1495813) log_secure: logging secure. ts=1495813
#   log > D (1495813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1495813) ringbuf_flash: WRITING hdr @ offset=5200 len=88 crc=0x290632699
#   log > D (1495813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1495813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1495813) nvs: nvs_set_blob log_secure 20
#   log > D (1495813) nvs: nvs_close 884
#   log > D (1495813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1495813) nvs: nvs_set_blob meta 44
#   log > D (1495813) nvs: nvs_close 885
#   log > D (1500813) log_secure: logging secure. ts=1500813
#   log > D (1500813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1500813) ringbuf_flash: WRITING hdr @ offset=5300 len=88 crc=0x3228179044
#   log > D (1500813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1500813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1500813) nvs: nvs_set_blob log_secure 20
#   log > D (1500813) nvs: nvs_close 886
#   log > D (1500813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1500813) nvs: nvs_set_blob meta 44
#   log > D (1500813) nvs: nvs_close 887
#   log > D (1505813) log_secure: logging secure. ts=1505813
#   log > D (1505813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1505813) ringbuf_flash: WRITING hdr @ offset=5400 len=88 crc=0x1213775362
#   log > D (1505813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1505813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1505813) nvs: nvs_set_blob log_secure 20
#   log > D (1505813) nvs: nvs_close 888
#   log > D (1505813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1505813) nvs: nvs_set_blob meta 44
#   log > D (1505813) nvs: nvs_close 889
#   log > D (1510813) log_secure: logging secure. ts=1510813
#   log > D (1510813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1510813) ringbuf_flash: WRITING hdr @ offset=5500 len=88 crc=0x4252359763
#   log > D (1510813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1510813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1510813) nvs: nvs_set_blob log_secure 20
#   log > D (1510813) nvs: nvs_close 890
#   log > D (1510813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1510813) nvs: nvs_set_blob meta 44
#   log > D (1510813) nvs: nvs_close 891
#   log > D (1515813) log_secure: logging secure. ts=1515813
#   log > D (1515813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1515813) ringbuf_flash: WRITING hdr @ offset=5600 len=88 crc=0x2171147809
#   log > D (1515813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1515813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1515813) nvs: nvs_set_blob log_secure 20
#   log > D (1515813) nvs: nvs_close 892
#   log > D (1515813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1515813) nvs: nvs_set_blob meta 44
#   log > D (1515813) nvs: nvs_close 893
#   log > D (1520813) log_secure: logging secure. ts=1520813
#   log > D (1520813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1520813) ringbuf_flash: WRITING hdr @ offset=5700 len=88 crc=0x1359507135
#   log > D (1520813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1520813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1520813) nvs: nvs_set_blob log_secure 20
#   log > D (1520813) nvs: nvs_close 894
#   log > D (1520813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1520813) nvs: nvs_set_blob meta 44
#   log > D (1520813) nvs: nvs_close 895
#   log > D (1525813) log_secure: logging secure. ts=1525813
#   log > D (1525813) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1525813) ringbuf_flash: WRITING hdr @ offset=5800 len=88 crc=0x2191277977
#   log > D (1525813) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1525813) nvs: nvs_open_from_partition rb_log 1
#   log > D (1525813) nvs: nvs_set_blob log_secure 20
#   log > D (1525813) nvs: nvs_close 896
#   log > D (1525813) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1525813) nvs: nvs_set_blob meta 44
#   log > D (1525863) nvs: nvs_close 897
#   log > D (1530863) log_secure: logging secure. ts=1530863
#   log > D (1530863) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1530863) ringbuf_flash: WRITING hdr @ offset=5900 len=88 crc=0x1032901155
#   log > D (1530863) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1530863) nvs: nvs_open_from_partition rb_log 1
#   log > D (1530863) nvs: nvs_set_blob log_secure 20
#   log > D (1530863) nvs: nvs_close 898
#   log > D (1530863) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1530863) nvs: nvs_set_blob meta 44
#   log > D (1530863) nvs: nvs_close 899
#   log > D (1535863) log_secure: logging secure. ts=1535863
#   log > D (1535863) ringbuf_flash: ringbuf_flash_write writing log...
#   log > D (1535863) ringbuf_flash: WRITING hdr @ offset=6000 len=88 crc=0x2106293579
#   log > D (1535863) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1535863) nvs: nvs_open_from_partition rb_log 1
#   log > D (1535863) nvs: nvs_set_blob log_secure 20
#   log > D (1535863) nvs: nvs_close 900
#   log > D (1535863) nvs: nvs_open_from_partition log_secure_nvs 1
#   log > D (1535863) nvs: nvs_set_blob meta 44
#   log > D (1535863) nvs: nvs_close 901
#   log > I (1539163) main: received command. cmd=log_dump
#   log > D (1539163) log_secure: dumping secure logs...
#   log > D (1539163) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539163) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539163) nvs: nvs_set_blob log_secure 20
#   log > D (1539173) nvs: nvs_close 902
#   log > log_dump:7727525A32B3F0C04CFA2D3A3B501300C64BEA1A56169700A4FAE14D65CDF7AA4AE0CB38A11051C9E18BFC1275F52F8C7B792302B481CB688F0D2A89CE98DAE7C2179BF5D12F626DFDDC0D78B1B44222A61D99DC7AEBEAFE
#   log > D (1539173) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539173) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539173) nvs: nvs_set_blob log_secure 20
#   log > D (1539173) nvs: nvs_close 903
#   log > log_dump:FDDC0D78B1B44222A61D99DCC36313001B0D54DCD5F36CEA51778F57BE57590053D5B2EDA875346D4CA40494A63DE541B35AF7733704F892972AE58340D7E7479A077459196C03DD2BFA12458C585CBCC7D8C82C1B0F689A
#   log > D (1539173) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539173) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539173) nvs: nvs_set_blob log_secure 20
#   log > D (1539183) nvs: nvs_close 904
#   log > log_dump:2BFA12458C585CBCC7D8C82C4B7713006AEF0ED40CE720B4559D889B1295C3C93C83EFD3A93C1DACA5B899BB260E1B42F98852D6263E2521CA71421175946F9702614B0B2B2D396CB7879E2B05E2830BAB051FC7DCCB5680
#   log > D (1539183) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539183) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539183) nvs: nvs_set_blob log_secure 20
#   log > D (1539183) nvs: nvs_close 905
#   log > log_dump:B7879E2B05E2830BAB051FC7D38A130014D5F5B4BD5DABBD471C8DA1785D6C71782B03F9D75EB3BE250E5B584A3105EABF186BC09D27D09C8619C7EDC54EE87486EF318C4EE79921CA0C3F973BFD35CF308F39C552307C0A
#   log > D (1539183) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539183) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539183) nvs: nvs_set_blob log_secure 20
#   log > D (1539183) nvs: nvs_close 906
#   log > log_dump:CA0C3F973BFD35CF308F39C55B9E1300063ADEFB2A9F2DD7A529947DAEE328A2BE1F1C7184D0BDD478B4027460B398C240974D3892FB14722D6C5B4F549F142C6EFF642F28CBCEF8C96C2CC900437D72933770243E439609
#   log > D (1539183) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539183) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539183) nvs: nvs_set_blob log_secure 20
#   log > D (1539203) nvs: nvs_close 907
#   log > log_dump:C96C2CC900437D7293377024E3B11300E931F0EFCD522C6A690B201083AA244E204203C08297452F49E5D180D016100536B0A34F3B916F9DDB8D620428693CC9717C92F707DB1A2F6BB4B4A07AEA41A54A4853D770BFDE60
#   log > D (1539203) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539203) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539203) nvs: nvs_set_blob log_secure 20
#   log > D (1539203) nvs: nvs_close 908
#   log > log_dump:6BB4B4A07AEA41A54A4853D76BC513008EC2EF167EF417C8926E394593D7B871382C19D7C617F0E00C7D8A1A3B8BADBFDB920EA22258D24E4FFB51CA790691FB9EDC47AC4FB4E4676F681AAA9F1B59D3171D444D9271910B
#   log > D (1539203) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539203) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539203) nvs: nvs_set_blob log_secure 20
#   log > D (1539213) nvs: nvs_close 909
#   log > log_dump:6F681AAA9F1B59D3171D444DF3D81300947F129EDE3580A51F519562423B7B1EC347ED2A103165145BA151B373FBBFA64EFC745F9D33D8E1E2ED2F63C446604167E53A4F1CBFDC0A04CFC002E1DEA4B087C40D4E0108FD97
#   log > D (1539213) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539213) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539213) nvs: nvs_set_blob log_secure 20
#   log > D (1539213) nvs: nvs_close 910
#   log > log_dump:04CFC002E1DEA4B087C40D4E7BEC13006485950EEA6DF59B20D3C4F7B5DBFF606E6FB0FC0A11C2E3F33D26CE48811D44273BEB055D0C7CFF37D6FB7E6AEC44125A5B96D60EBCE238669C60F884DF75EDAD2CDE09AF017102
#   log > D (1539213) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539213) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539213) nvs: nvs_set_blob log_secure 20
#   log > D (1539213) nvs: nvs_close 911
#   log > log_dump:669C60F884DF75EDAD2CDE09030014002F4DA3502E5D6EF644CD8F58701BE79944A148DFD4FF56D55AF62A3A79A6716FE96D32F291E95B127AE3CF68DE7A3E550C2F21E7381FB23CAA08001F3E42EAD5463F83EDE53C1DFA
#   log > D (1539213) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539213) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539213) nvs: nvs_set_blob log_secure 20
#   log > D (1539233) nvs: nvs_close 912
#   log > log_dump:AA08001F3E42EAD5463F83ED8B131400F2600DBA3D8907B5E3275366B848DBC5B2EB5D352FC35CAB06207EDE00BE95F2175F565541347CC7DBB041F35A52BB5DEED93B53FF6025970EE10937D1B337047D904A89FC1F2F48
#   log > D (1539233) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539233) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539233) nvs: nvs_set_blob log_secure 20
#   log > D (1539233) nvs: nvs_close 913
#   log > log_dump:0EE10937D1B337047D904A891327140093575093832A5CA585BC4A97FC3DEF82396BB89DB586F475D89C83B73189E1AA25B81CB3170D4675A86DFFB74EB5F49120F28F5F86F0E867C764BEAB974722BF2162EFD3D928EECB
#   log > D (1539233) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539233) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539233) nvs: nvs_set_blob log_secure 20
#   log > D (1539233) nvs: nvs_close 914
#   log > log_dump:C764BEAB974722BF2162EFD39B3A14002BCA66918CEBEF85D0FCCB2FED59321A5148258AAAB668EE130931FA4AAE8934D3CD50A02E5087361CA21C57CA824CE280823F69FD765B8F9A292994DA83906C010D5B1CF2F9D12B
#   log > D (1539243) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539243) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539243) nvs: nvs_set_blob log_secure 20
#   log > D (1539243) nvs: nvs_close 915
#   log > log_dump:9A292994DA83906C010D5B1C234E14008712450F06405F40A01CF631A42E392D5143C4C237B008D453BB881B0D92B813FE7207658A6487A12072AED3D56254538E59FACDA8D70560DD279569ACCDB3A987F078B1477CA2A5
#   log > D (1539243) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539243) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539243) nvs: nvs_set_blob log_secure 20
#   log > D (1539243) nvs: nvs_close 916
#   log > log_dump:DD279569ACCDB3A987F078B1AB611400A442EEFFE162F5D4F9D74EA4268BC8A3345C17175B7DDC0F53ABB69A022F60CA57E306906E7E27AB015B10AF188C786E47D8A4E43BEF5A36B2A1AAC05202A184431364AFCBAD0F88
#   log > D (1539243) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539243) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539243) nvs: nvs_set_blob log_secure 20
#   log > D (1539263) nvs: nvs_close 917
#   log > log_dump:B2A1AAC05202A184431364AF3375140062EF01D3AA5BE7D65340CE183AA2BFED96B0B7FA53252945DF803A69DD22F1921938367E662B7433562D21A55B9E468D0FF249D110671851FA4D7AC7C15837ED91221AD98504F15E
#   log > D (1539263) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539263) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539263) nvs: nvs_set_blob log_secure 20
#   log > D (1539263) nvs: nvs_close 918
#   log > log_dump:FA4D7AC7C15837ED91221AD9BB88140004C7F9D3B78E8610B91F9AF8F1672E7C05EC38C7D9C04CCFF3C7A05B489742269AB5C23B7CB55CCB841967F92354BE80673AFD6FE3060496AF1509648FD8A505C3BB9503D8109FED
#   log > D (1539263) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539263) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539263) nvs: nvs_set_blob log_secure 20
#   log > D (1539263) nvs: nvs_close 919
#   log > log_dump:AF1509648FD8A505C3BB9503439C14005E7315EAFA2B1E33EA6233812C56378D6A7007EB0BF0E2276E50F94A2A13259B3D39E3C6CF16A0152D958B6ABA3D0DDBDB792765AAAF014837E1BD91384084024BB3922118CB0A1B
#   log > D (1539273) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539273) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539273) nvs: nvs_set_blob log_secure 20
#   log > D (1539273) nvs: nvs_close 920
#   log > log_dump:37E1BD91384084024BB39221FDAF14000436FE4EA89E946D862E6416C1DBB0A2192DA093476A36439FCA2F094F31B05CBD660C4335CF05956B63E62F0E78C03C15148704B70DC8EBD05B20D566EEA4EE1BD41610B3193474
#   log > D (1539273) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539273) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539273) nvs: nvs_set_blob log_secure 20
#   log > D (1539273) nvs: nvs_close 921
#   log > log_dump:D05B20D566EEA4EE1BD4161085C3140054757C080E29F2A47A15A9E370380783C0428403B43F4CF0DEDD57E055BF9ACE9D7F2334740D7E44B64E12E13A569DC4BD9FD18A956273F09FA1510A78CE996978E6D1BD0972FA3C
#   log > D (1539273) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539273) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539273) nvs: nvs_set_blob log_secure 20
#   log > D (1539293) nvs: nvs_close 922
#   log > log_dump:9FA1510A78CE996978E6D1BD0DD71400F03D76E2386FE1469EDC11572966A996F0F9C007CDA6E89F8ED180F033AF9FF40241D993655F98DA6286B42021DDEEE57A866C94CD6ADB9241F790C6BA2B7B4EF8B72B5A5E20F5CE
#   log > D (1539293) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539293) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539293) nvs: nvs_set_blob log_secure 20
#   log > D (1539293) nvs: nvs_close 923
#   log > log_dump:41F790C6BA2B7B4EF8B72B5A95EA1400F9E42783E99CA192096614463BE2B06A6F53D85E25E26F3509CCF19CAF23B09E9F42E3D9516D6BB759C64976D209B9ACFEA9DD0DD95079A001383BC1724A7DB0E7422BC882DC44F3
#   log > D (1539293) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539293) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539293) nvs: nvs_set_blob log_secure 20
#   log > D (1539293) nvs: nvs_close 924
#   log > log_dump:01383BC1724A7DB0E7422BC81DFE1400454594E85CEE7B2FE46A76C5DA34ED6007F439609009861532AC85F0E84CFC03EA25A6D35D5039A8738D620D532105263A26041E1F1A43E59AF1864E1E8B2A1CCFA83AAB045B22A9
#   log > D (1539303) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539303) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539303) nvs: nvs_set_blob log_secure 20
#   log > D (1539303) nvs: nvs_close 925
#   log > log_dump:9AF1864E1E8B2A1CCFA83AABA5111500EA2BF33347DDE24104C86D96B469CD547877E7E1B9FB02D625A60942BDA3A16CE945A3D0DD3876E8FA1F9E7312726A2B7E4C3C420E319E79B9AF8C58900D1D7C8271B76DAA4F218E
#   log > D (1539303) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539303) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539303) nvs: nvs_set_blob log_secure 20
#   log > D (1539303) nvs: nvs_close 926
#   log > log_dump:B9AF8C58900D1D7C8271B76D2D25150014DA8097EEA64ADC8088846846F023727691FC170FA1223A514C1EBCA0E7E0E6055EB1FCEEFFA29AB32BC82A0EFB480F6CA90C21A0413A18ADBAC57C98B125A3F40A39B1E9CA5E0C
#   log > D (1539303) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539303) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539303) nvs: nvs_set_blob log_secure 20
#   log > D (1539323) nvs: nvs_close 927
#   log > log_dump:ADBAC57C98B125A3F40A39B1B5381500A4A510B54D1B0E8B263A4D2D48A6E6AEBFD5D8E5B4A622D4C8978B6E30AA3082E0E6936AC3EDD452D59BB358B9B0E2380A06D4E67D31BCFAFF731E0BABB6260AFB93EAA201B1F6CB
#   log > D (1539323) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539323) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539323) nvs: nvs_set_blob log_secure 20
#   log > D (1539323) nvs: nvs_close 928
#   log > log_dump:FF731E0BABB6260AFB93EAA23D4C15004B10B72F52A947F92A66835AAE6ED7421CE2E019AB43575B3BA7076B2CAA8333F114B28134E67C4916B036ECB980DD6F0606986B9818578505B673505367597E683B62E7BAF36D0E
#   log > D (1539323) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539323) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539323) nvs: nvs_set_blob log_secure 20
#   log > D (1539323) nvs: nvs_close 929
#   log > log_dump:05B673505367597E683B62E7C55F1500ACA137BD57F41009F5801D13F7F4B16F85820AA0697EACF80777C45BE088B6CF324F67976CA9E2C062648355A115E8F83EDC6B486CE849D2A976EC9EA21813C4B3EE042926C8030C
#   log > D (1539333) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539333) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539333) nvs: nvs_set_blob log_secure 20
#   log > D (1539333) nvs: nvs_close 930
#   log > log_dump:A976EC9EA21813C4B3EE04294D731500C7AF6C0C510FC41BEADEEDE58567AFC88ADCF684496EECE6851A457E186107BEF5E54197F3CADD87F63FC707C8571E204324A1D8985FAF671E649051BFDA53A0DF738512526887EC
#   log > D (1539333) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539333) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539333) nvs: nvs_set_blob log_secure 20
#   log > D (1539333) nvs: nvs_close 931
#   log > log_dump:1E649051BFDA53A0DF738512D5861500043184286518A0096250F22C820E8D269270F7FF5212140D8718A7C9E491A050711D4F6A856E7908AC3CA93A5A81472CADF76BE501B184295021A6222A37EFEC0C4CF677986321B9
#   log > D (1539333) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539333) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539333) nvs: nvs_set_blob log_secure 20
#   log > D (1539353) nvs: nvs_close 932
#   log > log_dump:5021A6222A37EFEC0C4CF6775D9A15005ADD9DF64D7F8C4E672FED4F7F5E51F515870854CB707C2E44ECA6FB3AE5210A9ACE950EC0AA22859857E86BD191327815A37465F41471A6DCD6831B458E92D6D240C6695B81AAA2
#   log > D (1539353) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539353) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539353) nvs: nvs_set_blob log_secure 20
#   log > D (1539353) nvs: nvs_close 933
#   log > log_dump:DCD6831B458E92D6D240C669E5AD15002E72DEC43B55D1803AFD18C9C7722AE930C8D4C2F371F8BC3D6A01C753683108A5A812E0364E06A8FDF887F8B8802030302951D282B7CC9D03300A23AF39F34A243633127FB3A82E
#   log > D (1539353) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539353) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539353) nvs: nvs_set_blob log_secure 20
#   log > D (1539353) nvs: nvs_close 934
#   log > log_dump:03300A23AF39F34A243633126DC11500B7C131E460626A79B4E06B757AD4BE26C52458C991CCAB984E1D539610D4A4F1C820B68E5C4AA423442438CAB4D046B6F323AFE113F6435222EA895ABFB235DD8C9ED7B4FB071A03
#   log > D (1539363) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539363) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539363) nvs: nvs_set_blob log_secure 20
#   log > D (1539363) nvs: nvs_close 935
#   log > log_dump:22EA895ABFB235DD8C9ED7B4F5D415002D6D23DC3EC17CA12194B21EB859CBD084672A4DE0463470E4B73D1D49F41F933A2D25FAF8DFC83BA1B9B89A907FD284CFA39FD345B00E3E53DADC1A1BC312FD00A2E53A9D3DA2F2
#   log > D (1539363) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539363) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539363) nvs: nvs_set_blob log_secure 20
#   log > D (1539363) nvs: nvs_close 936
#   log > log_dump:53DADC1A1BC312FD00A2E53A7DE815006067A573906C5D41A339510528D34EAC97D6E15A47116CB4DAEF221F2DF7AE98918D5BCC3431C6CB9C5BB58D1AC8CB4DB102600F506163ADB7AC7A121C073F075A04DEC4F5EC5B95
#   log > D (1539363) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539363) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539363) nvs: nvs_set_blob log_secure 20
#   log > D (1539413) nvs: nvs_close 937
#   log > log_dump:B7AC7A121C073F075A04DEC42DFC150069A12FA03805575C70E8C7E348B2FFCCACF4C8BFC95222CF3A57C894E8EA53C08DFBD9A53DE0395E848093E65B983E510F0F1A4DB1AC7B8F7F6C25CC0BFCD123C54B940FEF0A78AA
#   log > D (1539413) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539413) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539413) nvs: nvs_set_blob log_secure 20
#   log > D (1539413) nvs: nvs_close 938
#   log > log_dump:7F6C25CC0BFCD123C54B940FB50F1600400F2FAD50F3200EA161ADA87A12A7CC0D04BE6FC889B9BB2826EB87C2B714CD0E6410BD6E272976B35C4BF36F47083706D74425A28C6904C83C8E75CB0BBBA94BF32F45F5768731
#   log > D (1539413) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539413) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539413) nvs: nvs_set_blob log_secure 20
#   log > D (1539423) nvs: nvs_close 939
#   log > log_dump:C83C8E75CB0BBBA94BF32F453D23160031FBB2FF5FF9CE3DAF42D12A468716BE6EB69AEC6C6A8A9380948D29B8418D5A8514834FC9FA8AF408DD2C8000D2B3391087F33857A94CC13F979384102855447F4929A573C914C8
#   log > D (1539423) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539423) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539423) nvs: nvs_set_blob log_secure 20
#   log > D (1539423) nvs: nvs_close 940
#   log > log_dump:3F979384102855447F4929A5C5361600C3AC52891052E95DE2EA9EBE1254396BF88BC9C0B99FDF228ED65FA47F88A7A9B4674DC8244BE383C5104498AA70ACF9D276ACBD73FA012FE73CD9ECA840F8B4F739287167D522FB
#   log > D (1539423) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539423) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539423) nvs: nvs_set_blob log_secure 20
#   log > D (1539423) nvs: nvs_close 941
#   log > log_dump:E73CD9ECA840F8B4F73928714D4A1600107FCE3C9539FB92EDF0791C8329F890A8297150A5E98884FAC49A8A8B44C80A72B736B5E8CF2318DF2F9EA18A8262A0F7C2DF2A42956EDFE6FD51C09D0940A21F6715BAA2F29B63
#   log > D (1539423) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539423) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539423) nvs: nvs_set_blob log_secure 20
#   log > D (1539443) nvs: nvs_close 942
#   log > log_dump:E6FD51C09D0940A21F6715BAD55D1600FC55950C98B0DDED29CE001532B2C7D7C34096685864B7661F1119FA175ABD4B6D3F4CB1DDCC307B6C8228F3614A551856FA46C9912C61DB3247259B8633A85AA3110AC96835BBEE
#   log > D (1539443) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539443) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539443) nvs: nvs_set_blob log_secure 20
#   log > D (1539443) nvs: nvs_close 943
#   log > log_dump:3247259B8633A85AA3110AC95D7116001D3D32F39481DCCF7FF32F89F9B65B7E70E3C9A359BD8C6C893A2E3CBBE8149FD065CFD2E32D00504892FC1E3A612F8FFB3A86AD82C3AF1E5D198DA6FF44C91BBA7793FF019450CC
#   log > D (1539443) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539443) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539443) nvs: nvs_set_blob log_secure 20
#   log > D (1539453) nvs: nvs_close 944
#   log > log_dump:5D198DA6FF44C91BBA7793FFE58416003CB907E898C9A0B6E55FFD3AADE2A3FF6D0284DC169FC4F404C8BC464EBD9B95BEA6157B490342BF16E31EAC5CED51A1755BBABED648734839AE1BB08A6F1CF8B7BF4C4C7830E40D
#   log > D (1539453) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539453) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539453) nvs: nvs_set_blob log_secure 20
#   log > D (1539453) nvs: nvs_close 945
#   log > log_dump:39AE1BB08A6F1CF8B7BF4C4C6D981600E506BCFB3FDCEDAE513A74B975C35EA34E202460ADE7EDA403DE1B4B89F1E21E2649D411D73C560232E22740E19831DE94BEDFCC4783F1F1825E757A72C7A54DEB306E502E8FB029
#   log > D (1539453) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539453) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539453) nvs: nvs_set_blob log_secure 20
#   log > D (1539453) nvs: nvs_close 946
#   log > log_dump:825E757A72C7A54DEB306E50F5AB160097329AB683682497F38F3B5274F171B4CA8338FDD3572B154D4CF16DCF5A281F700AF667C4127B48BE8A89072B3ABCE6DBA3215C89309DD2EFEF96FD109966AD67E7B13660C99C7C
#   log > D (1539453) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539453) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539453) nvs: nvs_set_blob log_secure 20
#   log > D (1539473) nvs: nvs_close 947
#   log > log_dump:EFEF96FD109966AD67E7B1367DBF1600AA7108A73683D382DA3DE5B393578AF5E66430EC24432A4CD8D9ABA551EBCB77CA7C15359FAAB0337FD679E723263ED705E5E57BF0BF330C9A812BAB63AE0A5470810EA3ACA1031F
#   log > D (1539473) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539473) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539473) nvs: nvs_set_blob log_secure 20
#   log > D (1539473) nvs: nvs_close 948
#   log > log_dump:9A812BAB63AE0A5470810EA305D316009F1D0FA2027669D34129C4CC7B4E99BFD8C34FC44B77A018C420EC843AAE2B787C64DBB3D0725D5E680DBA94129B67E8240AA47AB5F97115A3FB6F0B439AFF6E2652E204F5DF7E6F
#   log > D (1539473) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539473) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539473) nvs: nvs_set_blob log_secure 20
#   log > D (1539483) nvs: nvs_close 949
#   log > log_dump:A3FB6F0B439AFF6E2652E2048DE6160088B418F1A41B219455525A532D16FAA8C7968B2E548AE081F904F687AC3DBB4CFC02EA17430AFB2C476EECDC0A4B36CA69E56A7888B07440E099E7F8830C83F9F101275A7D2DF83E
#   log > D (1539483) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539483) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539483) nvs: nvs_set_blob log_secure 20
#   log > D (1539483) nvs: nvs_close 950
#   log > log_dump:E099E7F8830C83F9F101275A15FA1600399362FB0C588A3D55D464737635BCA89424D195F8AEA08CA16A88CD54D55E2EB184852229907B15542D4CBFCE697D3F1B0A3656AC075C2B11DF3BBAED48319409C36EFDC45A45AF
#   log > D (1539483) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539483) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539483) nvs: nvs_set_blob log_secure 20
#   log > D (1539483) nvs: nvs_close 951
#   log > log_dump:11DF3BBAED48319409C36EFD9D0D1700291B5FC4210CB5AFC109F6A3CC3B69E76D6B2CC3A448693A4A5713AC51E25CB57F405D7E270EF9CA81C61CA32295805C678BDFD3490DF3E54FD1367E2C1D385F931F73D5E87FE69E
#   log > D (1539483) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539483) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539483) nvs: nvs_set_blob log_secure 20
#   log > D (1539503) nvs: nvs_close 952
#   log > log_dump:4FD1367E2C1D385F931F73D5252117000B50254AE946DEEF8981FA24FB7796859B80CE20772037BA3E9D45C223F609BDAA983AA6EE578AF526EB2DBFEDB144DB02A400BA8F5A05C5B25FB4F54359830D6236BF7CEB8D2E16
#   log > D (1539503) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539503) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539503) nvs: nvs_set_blob log_secure 20
#   log > D (1539503) nvs: nvs_close 953
#   log > log_dump:B25FB4F54359830D6236BF7CAD34170014B4B8EA1A14B12F97AEE35125B25A6B81ECA9C8E7A7CF41BB6328D4665CE108DA43E6CF714B2FFC78FBA9413AE5D254BDEC710DAC5DA9A8241DC184D92F2E0B29EDF5BCB554D70B
#   log > D (1539503) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539503) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539503) nvs: nvs_set_blob log_secure 20
#   log > D (1539513) nvs: nvs_close 954
#   log > log_dump:241DC184D92F2E0B29EDF5BC354817007EE7D05B8DEE239AB27DE00470090445BF86D8ED66B4F66E9F25C804AD39F75850A940755C4345AE8371F85F31711052AE65C1B44E82432FCD53D7B4EEA7BB4E88F6A5C3FDD96954
#   log > D (1539513) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539513) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539513) nvs: nvs_set_blob log_secure 20
#   log > D (1539513) nvs: nvs_close 955
#   log > log_dump:CD53D7B4EEA7BB4E88F6A5C3EF5B1700BD4B2C0C5E3EA8473C5FBEDD66F180B312C8647248CD202DE96C8B3A486B4A70614EFB25439B937783E409E4AC04A45BAA970476D80CF0B1C3CEDA53E2781C57FE29287357160EBD
#   log > D (1539513) ringbuf_flash: Saving ringbuf metadata...
#   log > D (1539513) nvs: nvs_open_from_partition rb_log 1
#   log > D (1539513) nvs: nvs_set_blob log_secure 20
#   log > D (1539513) nvs: nvs_close 956
#   log > log_dump:C3CEDA53E2781C57FE292873776F1700137EE06097C929C1937460422FB211D19F07A397C154CBD4640CAD475D8A547BA1684E5A2D03C3FF3E1A39544010A44486FF1F345C1CBC78E0830A15307D39325FAAE4F53DEDD0C4
# footer: received 55 logs.

# %%
results = verify_logs(audit_logs, key)
for tx, message in results: 
    print(f"{tx}: {message}")
# Out:
# 1265723: b'   1265723 [main]: system running smoothly. counter=253\n'
# 1270723: b'   1270723 [main]: system running smoothly. counter=254\n'
# 1275723: b'   1275723 [main]: system running smoothly. counter=255\n'
# 1280723: b'   1280723 [main]: system running smoothly. counter=256\n'
# 1285723: b'   1285723 [main]: system running smoothly. counter=257\n'
# 1290723: b'   1290723 [main]: system running smoothly. counter=258\n'
# 1295723: b'   1295723 [main]: system running smoothly. counter=259\n'
# 1300723: b'   1300723 [main]: system running smoothly. counter=260\n'
# 1305723: b'   1305723 [main]: system running smoothly. counter=261\n'
# 1310723: b'   1310723 [main]: system running smoothly. counter=262\n'
# 1315723: b'   1315723 [main]: system running smoothly. counter=263\n'
# 1320723: b'   1320723 [main]: system running smoothly. counter=264\n'
# 1325723: b'   1325723 [main]: system running smoothly. counter=265\n'
# 1330723: b'   1330723 [main]: system running smoothly. counter=266\n'
# 1335723: b'   1335723 [main]: system running smoothly. counter=267\n'
# 1340723: b'   1340723 [main]: system running smoothly. counter=268\n'
# 1345723: b'   1345723 [main]: system running smoothly. counter=269\n'
# 1350723: b'   1350723 [main]: system running smoothly. counter=270\n'
# 1355773: b'   1355773 [main]: system running smoothly. counter=271\n'
# 1360773: b'   1360773 [main]: system running smoothly. counter=272\n'
# 1365773: b'   1365773 [main]: system running smoothly. counter=273\n'
# 1370773: b'   1370773 [main]: system running smoothly. counter=274\n'
# 1375773: b'   1375773 [main]: system running smoothly. counter=275\n'
# 1380773: b'   1380773 [main]: system running smoothly. counter=276\n'
# 1385773: b'   1385773 [main]: system running smoothly. counter=277\n'
# 1390773: b'   1390773 [main]: system running smoothly. counter=278\n'
# 1395773: b'   1395773 [main]: system running smoothly. counter=279\n'
# 1400773: b'   1400773 [main]: system running smoothly. counter=280\n'
# 1405773: b'   1405773 [main]: system running smoothly. counter=281\n'
# 1410773: b'   1410773 [main]: system running smoothly. counter=282\n'
# 1415773: b'   1415773 [main]: system running smoothly. counter=283\n'
# 1420773: b'   1420773 [main]: system running smoothly. counter=284\n'
# 1425773: b'   1425773 [main]: system running smoothly. counter=285\n'
# 1430773: b'   1430773 [main]: system running smoothly. counter=286\n'
# 1435773: b'   1435773 [main]: system running smoothly. counter=287\n'
# 1440813: b'   1440813 [main]: system running smoothly. counter=288\n'
# 1445813: b'   1445813 [main]: system running smoothly. counter=289\n'
# 1450813: b'   1450813 [main]: system running smoothly. counter=290\n'
# 1455813: b'   1455813 [main]: system running smoothly. counter=291\n'
# 1460813: b'   1460813 [main]: system running smoothly. counter=292\n'
# 1465813: b'   1465813 [main]: system running smoothly. counter=293\n'
# 1470813: b'   1470813 [main]: system running smoothly. counter=294\n'
# 1475813: b'   1475813 [main]: system running smoothly. counter=295\n'
# 1480813: b'   1480813 [main]: system running smoothly. counter=296\n'
# 1485813: b'   1485813 [main]: system running smoothly. counter=297\n'
# 1490813: b'   1490813 [main]: system running smoothly. counter=298\n'
# 1495813: b'   1495813 [main]: system running smoothly. counter=299\n'
# 1500813: b'   1500813 [main]: system running smoothly. counter=300\n'
# 1505813: b'   1505813 [main]: system running smoothly. counter=301\n'
# 1510813: b'   1510813 [main]: system running smoothly. counter=302\n'
# 1515813: b'   1515813 [main]: system running smoothly. counter=303\n'
# 1520813: b'   1520813 [main]: system running smoothly. counter=304\n'
# 1525813: b'   1525813 [main]: system running smoothly. counter=305\n'
# 1530863: b'   1530863 [main]: system running smoothly. counter=306\n'
# 1535863: b'   1535863 [main]: system running smoothly. counter=307\n'

# %%
import copy
from cryptography.exceptions import InvalidTag

def test_tampering(audit_logs, key):
    NONCE_LEN = 12
    TAG_LEN   = 16

    def run_test(name, tamper_fn):
        logs = copy.deepcopy(audit_logs)
        tamper_fn(logs)
        try:
            _ = verify_logs(logs, key)
            print(f"❌ {name}: No tampering detected!")
        except ValueError as e:
            print(f"✅ {name}: Caught chain‐break: {e}")
        except InvalidTag:
            print(f"✅ {name}: Caught authentication failure (InvalidTag)")

    # 1) Flip a byte in ciphertext of record #2
    def tamper_cipher(logs):
        rec = bytearray(logs[2])
        rec[NONCE_LEN + 4 + 5] ^= 0xFF
        logs[2] = bytes(rec)

    # 2) Flip a bit in the AAD (timestamp) of record #3
    def tamper_aad(logs):
        rec = bytearray(logs[3])
        rec[NONCE_LEN + 1] ^= 0x01
        logs[3] = bytes(rec)

    # 3) Flip a byte in the auth‐tag of record #4
    def tamper_tag(logs):
        rec = bytearray(logs[4])
        rec[-1] ^= 0xAA
        logs[4] = bytes(rec)

    # 4) Flip a byte in the nonce of record #5 to force a chain break
    def tamper_nonce(logs):
        rec = bytearray(logs[5])
        rec[0] ^= 0x11
        logs[5] = bytes(rec)

    run_test("Ciphertext tamper", tamper_cipher)
    run_test("AAD tamper",        tamper_aad)
    run_test("Tag tamper",        tamper_tag)
    run_test("Nonce tamper",      tamper_nonce)

# Run it
test_tampering(audit_logs, key)
# Out:
# ✅ Ciphertext tamper: Caught authentication failure (InvalidTag)
# ✅ AAD tamper: Caught authentication failure (InvalidTag)
# ✅ Tag tamper: Caught authentication failure (InvalidTag)
# ✅ Nonce tamper: Caught chain‐break: Chain broken at record 5

# %%
def test_insertion(audit_logs, key):
    logs = list(audit_logs)
    # Pick an existing record and insert it at position 2
    logs.insert(2, logs[3])
    
    try:
        _ = verify_logs(logs, key)
        print("❌ Insert test: No tampering detected!")
    except ValueError as e:
        print("✅ Insert test: Caught chain‐break:", e)
    except InvalidTag:
        print("✅ Insert test: Caught authentication failure (InvalidTag)")

test_insertion(audit_logs, key)
# Out:
# ✅ Insert test: Caught chain‐break: Chain broken at record 2
